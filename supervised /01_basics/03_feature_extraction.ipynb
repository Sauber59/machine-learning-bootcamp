# %% [markdown]
# <a href="https://colab.research.google.com/github/Sauber59/machine-learning-bootcamp/blob/main/supervised%20/01_basics/03_feature_extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import sklearn

sklearn.__version__
# Out:
# '1.6.1'

# %% [markdown]
# ##zaladowanie danych

# %%
def fetch_financial_data(company='AMZN'):
    """
    This function fetches stock market quotations.
    """
    import pandas_datareader.data as web
    return web.DataReader(name=company, data_source='stooq')

df_raw = fetch_financial_data()
df_raw.head()
# Out:
#               Open     High     Low   Close    Volume
# Date
# 2025-02-28  209.06  212.620  206.99  212.28  51771737
# 2025-02-27  218.35  219.970  208.37  208.74  40548571
# 2025-02-26  214.94  218.160  213.09  214.35  39120603
# 2025-02-25  211.63  213.340  204.16  212.80  58957977
# 2025-02-24  217.45  217.715  212.42  212.71  42387585

# %% [markdown]
# ##utworzenie kopii

# %%
df = df_raw.copy()
df= df[:5]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5 entries, 2025-02-28 to 2025-02-24
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    5 non-null      float64
#  1   High    5 non-null      float64
#  2   Low     5 non-null      float64
#  3   Close   5 non-null      float64
#  4   Volume  5 non-null      int64
# dtypes: float64(4), int64(1)
# memory usage: 240.0 bytes

# %% [markdown]
# ##generownie nowych zmiennych

# %%
df['day'] = df.index.day
df['month'] = df.index.month
df['year'] = df.index.year
df
# Out:
#               Open     High     Low   Close    Volume  day  month  year
# Date
# 2025-02-28  209.06  212.620  206.99  212.28  51771737   28      2  2025
# 2025-02-27  218.35  219.970  208.37  208.74  40548571   27      2  2025
# 2025-02-26  214.94  218.160  213.09  214.35  39120603   26      2  2025
# 2025-02-25  211.63  213.340  204.16  212.80  58957977   25      2  2025
# 2025-02-24  217.45  217.715  212.42  212.71  42387585   24      2  2025

# %% [markdown]
# ##dykretyzacja danych
# generowanie danych przykladowych:

# %%
df = pd.DataFrame(data={'height': [175., 178.5, 185., 191., 184.5, 183., 168.]})
df
# Out:
#    height
# 0   175.0
# 1   178.5
# 2   185.0
# 3   191.0
# 4   184.5
# 5   183.0
# 6   168.0

# %% [markdown]
# ###podzial na zakresy

# %%
df['height_cat'] = pd.cut(x=df.height, bins=3)
df
# Out:
#    height          height_cat
# 0   175.0  (167.977, 175.667]
# 1   178.5  (175.667, 183.333]
# 2   185.0    (183.333, 191.0]
# 3   191.0    (183.333, 191.0]
# 4   184.5    (183.333, 191.0]
# 5   183.0  (175.667, 183.333]
# 6   168.0  (167.977, 175.667]

# %%
df['height_cat'] = pd.cut(x=df.height, bins=(160, 175, 180, 195), labels=('small', 'medium', 'high'))
df
# Out:
#    height height_cat
# 0   175.0      small
# 1   178.5     medium
# 2   185.0       high
# 3   191.0       high
# 4   184.5       high
# 5   183.0       high
# 6   168.0      small

# %% [markdown]
# ##ekstrakcja cech

# %%
df = pd.DataFrame(data={'lang': [['PL', 'ENG'], ['GER', 'ENG', 'PL', 'FRA'], ['RUS']]})
df
# Out:
#                   lang
# 0            [PL, ENG]
# 1  [GER, ENG, PL, FRA]
# 2                [RUS]

# %%
df['lang_number'] = df.lang.apply(len)
df
# Out:
#                   lang  PL_lang  lang_number
# 0            [PL, ENG]        1            2
# 1  [GER, ENG, PL, FRA]        1            4
# 2                [RUS]        0            1

# %%
df['PL_lang'] = df.lang.apply(lambda x: 1 if 'PL' in x else 0)
df
# Out:
#                   lang  PL_lang
# 0            [PL, ENG]        1
# 1  [GER, ENG, PL, FRA]        1
# 2                [RUS]        0

# %%
df = pd.DataFrame(data={'website':['wp.pl', 'onet.pl', 'google.com']})
df
# Out:
#       website
# 0       wp.pl
# 1     onet.pl
# 2  google.com

# %%
df_split = df.website.str.split('.', expand=True)
df_split
# Out:
#         0    1
# 0      wp   pl
# 1    onet   pl
# 2  google  com
